# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../water.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349440 entries, 0 to 349439
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   pH                      343521 non-null  float64
#  1   Iron                    347340 non-null  float64
#  2   Nitrate                 343938 non-null  float64
#  3   Chloride                340261 non-null  float64
#  4   Lead                    348023 non-null  float64
#  5   Zinc                    341312 non-null  float64
#  6   Turbidity               346914 non-null  float64
#  7   Fluoride                339486 non-null  float64
#  8   Copper                  339111 non-null  float64
#  9   Odor                    340138 non-null  float64
#  10  Sulfate                 339177 non-null  float64
#  11  Conductivity            340911 non-null  float64
#  12  Chlorine                346475 non-null  float64
#  13  Manganese               343632 non-null  float64
#  14  Total Dissolved Solids  349351 non-null  float64
#  15  Potability              349440 non-null  int64
# dtypes: float64(15), int64(1)
# memory usage: 42.7 MB

# %%
print(df.shape)        # size
# Out:
# (349440, 16)

# %%
print(df.isnull().sum())  # missing values
# Out:
# pH                         5919
# Iron                       2100
# Nitrate                    5502
# Chloride                   9179
# Lead                       1417
# Zinc                       8128
# Turbidity                  2526
# Fluoride                   9954
# Copper                    10329
# Odor                       9302
# Sulfate                   10263
# Conductivity               8529
# Chlorine                   2965
# Manganese                  5808
# Total Dissolved Solids       89
# Potability                    0
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)

# %%
X = df.drop("Potability", axis=1)
y = df["Potability"]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
df.to_csv("cleaned_water_data.csv", index=False)

# %%
df = pd.read_csv("cleaned_water_data.csv")

# %%
print(df.isnull().sum())
# Out:
# pH                        0
# Iron                      0
# Nitrate                   0
# Chloride                  0
# Lead                      0
# Zinc                      0
# Turbidity                 0
# Fluoride                  0
# Copper                    0
# Odor                      0
# Sulfate                   0
# Conductivity              0
# Chlorine                  0
# Manganese                 0
# Total Dissolved Solids    0
# Potability                0
# dtype: int64

# %%
df.to_csv("C:/Users/hardh/OneDrive/Desktop/ml project/project/cleaned_water_data.csv", index=False)
